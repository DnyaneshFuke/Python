# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
# %matplotlib inline
plt.xlabel("Years")
plt.ylabel("Income")
plt.scatter(df.year,df.income ,color="red" ,marker="+")

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']], df['income'])
# Out:
# LinearRegression()

# %%
reg.predict([[1969]])
# Out:
# c:\Users\Dnyanesh\Desktop\2024-code\Python\Machine_Learning\env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-963.02474194])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
d=pd.read_csv("R_Y.csv")
d[:5]
# Out:
#    year
# 0  2001
# 1  1973
# 2  1999
# 3  2006
# 4  1992

# %%
p=reg.predict(d)
d['Income']=p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 p=reg.predict(d)
#       2 d['Income']=p
#
# File c:\Users\Dnyanesh\Desktop\2024-code\Python\Machine_Learning\env\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Users\Dnyanesh\Desktop\2024-code\Python\Machine_Learning\env\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File c:\Users\Dnyanesh\Desktop\2024-code\Python\Machine_Learning\env\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File c:\Users\Dnyanesh\Desktop\2024-code\Python\Machine_Learning\env\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Income

# %%
d
# Out:
#     year        Income
# 0   2001  25547.857665
# 1   1973   2350.835559
# 2   1999  23890.927515
# 3   2006  29690.183041
# 4   1992  18091.671988
# 5   2008  31347.113192
# 6   2014  36317.903643
# 7   1984  11463.951386
# 8   2012  34660.973493
# 9   1998  23062.462440
# 10  2005  28861.717966
# 11  1982   9807.021236
# 12  2001  25547.857665
# 13  1976   4836.230785
# 14  2020  41288.694094
# 15  1991  17263.206913
# 16  1997  22233.997364
# 17  1971    693.905409
# 18  2011  33832.508417
# 19  2014  36317.903643
# 20  2022  42945.624245
# 21  1975   4007.765709
# 22  1997  22233.997364
# 23  1997  22233.997364
# 24  2013  35489.438568
# 25  2013  35489.438568
# 26  1989  15606.276763
# 27  1999  23890.927515
# 28  1980   8150.091086
# 29  1997  22233.997364
# 30  1994  19748.602139
# 31  2008  31347.113192
# 32  2002  26376.322740
# 33  1970   -134.559667
# 34  1996  21405.532289
# 35  2021  42117.159170
# 36  1982   9807.021236
# 37  2010  33004.043342
# 38  1972   1522.370484
# 39  2008  31347.113192
# 40  1975   4007.765709
# 41  1977   5664.695860
# 42  1996  21405.532289
# 43  1978   6493.160935
# 44  2006  29690.183041
# 45  2002  26376.322740
# 46  2020  41288.694094
# 47  2011  33832.508417
# 48  2013  35489.438568
# 49  1993  18920.137063

# %%
d.to_csv("Pridicted_Incomes.csv")
